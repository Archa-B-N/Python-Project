# %% [markdown]
# # Exploratory Data Analysis of Employees Working in ABC Company
#
# # Introduction
# Exploratory Data Analysis (EDA) is a process to understand and summarize datasets, identify patterns, and detect anomalies. It helps prepare data for analysis, improves model accuracy, and informs decision-making.
#
# # Project Overview
# This project aims to perform an exploratory data analysis on a dataset containing information about 458 NBA (National Basketball Association) players, initially perceived as employees working in ABC company.
# The dataset includes variables such as:
#
# - Age
# - Height
# - Weight
# - Position
# - Team
# - College
# - Salary
#
# This analysis will provide an overview of the distribution of these variables, identify potential relationships between them, and visualize key findings. The goal is to gain a deeper understanding of the characteristics of NBA players.
#
# # Dataset Overview
# The dataset consists of 458 rows and 9 columns, providing information about NBA players. The columns are:
#
# - Name
# - Team
# - Number (Jersey Number)
# - Position
# - Age
# - Height
# - Weight
# - College
# - Salary
#
# # Project Objectives
# The objectives of this project are:
#
# 1. Explore the distribution of players across teams and positions
# 2. Analyze the relationship between age, height, weight, and position
# 3. Investigate the correlation between salary and other factors (age, position, college)
# 4. Visualize key findings using plots and charts
#
# # Methodology
# The methodology used in this project involves:
#
# 1. Data preprocessing and cleaning
# 2. Data visualization and exploration
# 3. Statistical analysis and modeling
#
# # Preprocessing Steps
# The following steps were taken to preprocess the data:
#
# 1. Import necessary libraries: pandas, numpy, matplotlib, and seaborn were imported to facilitate data manipulation and visualization.
#
# 2. Load the dataset: The Excel file was loaded using pd.read_excel().
#
# 3. Check for missing values: df.isnull().sum() was used to identify missing values in the dataset.
#
# 4. Handle missing values: A strategy was decided upon to handle missing values, such as mean/median imputation or removal.
#
# 5. Correct Height column: The Height column was corrected by replacing height values with numbers between 150-180 using df['Height'].apply().

# %%
#Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Load dataset
df = pd.read_excel('myexcel.xlsx')

#Check for missing values
print("Missing Values:")
print(df.isnull().sum())

#Correct Height column: replace with random values between 150-180
df['Height'] = df['Height'].apply(lambda x: np.random.randint(150, 180))

#Verify corrections
print("\nHeight Column Corrections:")
print(df['Height'].describe())
# Out:
# Missing Values:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64
#
# Height Column Corrections:
# count    458.000000
# mean     164.814410
# std        8.445374
# min      150.000000
# 25%      158.000000
# 50%      165.000000
# 75%      172.000000
# max      179.000000
# Name: Height, dtype: float64

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     164     235
# 2     John Holland  Boston Celtics      30       SG   27     151     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     166     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     161     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     160     203
# 454      Raul Neto       Utah Jazz      25       PG   24     162     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     155     256
# 456    Jeff Withey       Utah Jazz      24        C   26     171     231
# 457       Priyanka       Utah Jazz      34        C   25     173     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
null_percentage = (df['College'].isnull().sum() / len(df)) * 100
print("Percentage of null values in 'College",null_percentage,"%")
# Out:
# Percentage of null values in 'College 18.340611353711793 %

# %% [markdown]
# #### #Missing Values
#
# The output shows that there are:
#
# - 84 missing values in the "College" column
# - 11 missing values in the "Salary" column
# - No missing values in the other columns

# %%
# Handle Missing Values


# Replace blank names with 'Unknown'

df['College'] = df['College'].fillna('Unknown')

# Calculate average salary

average_salary = df['Salary'].mean()
print("average salary=",average_salary)

# Replace empty salary values with average salary

df['Salary'].fillna(average_salary, inplace=True)


# Display updated dataframe

df
# Out:
# average salary= 4833969.545861297
# C:\Users\HP\AppData\Local\Temp\ipykernel_2168\2247674797.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Salary'].fillna(average_salary, inplace=True)
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     171     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     155     235
# 2     John Holland  Boston Celtics      30       SG   27     168     205
# ...

# %%
# Save updated dataset
df.to_excel('updated_abc_company_data.xlsx', index=False)

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     171     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     155     235
# 2   John Holland  Boston Celtics      30       SG   27     168     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     152     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     167     231
#
#              College        Salary
# 0              Texas  7.730337e+06
# 1          Marquette  6.796117e+06
# 2  Boston University  4.833970e+06
# 3      Georgia State  1.148640e+06
# 4            Unknown  5.000000e+06

# %%
df.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight  College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26     169     203   Butler
# 454     Raul Neto  Utah Jazz      25       PG   24     155     179  Unknown
# 455  Tibor Pleiss  Utah Jazz      21        C   26     168     256  Unknown
# 456   Jeff Withey  Utah Jazz      24        C   26     168     231   Kansas
# 457      Priyanka  Utah Jazz      34        C   25     169     231   Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
df.describe(include='all')
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int64
#  6   Weight    458 non-null    int64
#  7   College   458 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 32.3+ KB

# %%
#To check if there are any missing values
df.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
#To check if there are any duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     171     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     155     235
# 2     John Holland  Boston Celtics      30       SG   27     168     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     152     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     167     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     169     203
# 454      Raul Neto       Utah Jazz      25       PG   24     155     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     168     256
# 456    Jeff Withey       Utah Jazz      24        C   26     168     231
# 457       Priyanka       Utah Jazz      34        C   25     169     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %% [markdown]
# # Analysis Tasks:
# # 1. Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees.

# %%
#Step 2: Calculate team distribution


# Calculate team distribution
team_distribution = df['Team'].value_counts()

# Calculate percentage split
percentage_split = (team_distribution / len(df)) * 100

# Combine results
team_distribution_percentage = pd.concat([team_distribution, percentage_split], axis=1)

# Rename columns
team_distribution_percentage.columns = ['Count', 'Percentage']

# Print results
print(team_distribution_percentage)
# Out:
#                         Count  Percentage
# Team
# New Orleans Pelicans       19    4.148472
# Memphis Grizzlies          18    3.930131
# Utah Jazz                  16    3.493450
# New York Knicks            16    3.493450
# Milwaukee Bucks            16    3.493450
# Brooklyn Nets              15    3.275109
# Portland Trail Blazers     15    3.275109
# Oklahoma City Thunder      15    3.275109
# Denver Nuggets             15    3.275109
# Washington Wizards         15    3.275109
# Miami Heat                 15    3.275109
# Charlotte Hornets          15    3.275109
# Atlanta Hawks              15    3.275109
# San Antonio Spurs          15    3.275109
# Houston Rockets            15    3.275109
# Boston Celtics             15    3.275109
# Indiana Pacers             15    3.275109
# Detroit Pistons            15    3.275109
# Cleveland Cavaliers        15    3.275109
# Chicago Bulls              15    3.275109
# Sacramento Kings           15    3.275109
# ...

# %% [markdown]
# # NBA Players Team Distribution Chart

# %%
# Visualize team distribution 

# Bar chart
plt.figure(figsize=(20, 9))
plt.bar(team_distribution_percentage.index, team_distribution_percentage['Count'],color='#87CEEB')
plt.xlabel('Team')
plt.ylabel('Count')
plt.title('Team Distribution')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# # Data story based on the team distribution and percentage split:
#
#
# The NBA comprises 30 teams, each with a unique roster.
#
# Our analysis reveals that the New Orleans Pelicans have the highest number of players, with 19 players on their roster, accounting for 4.15% of the total NBA players.
#
# The Memphis Grizzlies follow closely, with 18 players, making up 3.93% of the total NBA players.
#
# Interestingly, 24 teams have 15 players each, indicating a relatively even distribution of players across the league.
#
# The Orlando Magic and Minnesota Timberwolves have the lowest number of players, with 14 players each, accounting for 3.06% of the total NBA players.
#
# These insights provide a fascinating glimpse into the world of NBA team dynamics and player distribution.

# %% [markdown]
# # 2.Segregate employees based on their positions within the company.

# %%
# Calculate position distribution
position_distribution = df['Position'].value_counts()

# Calculate percentage split
percentage_split = (position_distribution / len(df)) * 100

# Combine results
position_distribution_percentage = pd.concat([position_distribution, percentage_split], axis=1)

# Rename columns
position_distribution_percentage.columns = ['Count', 'Percentage']

# Print results
print(position_distribution_percentage)
# Out:
#           Count  Percentage
# Position
# SG          102   22.270742
# PF          100   21.834061
# PG           92   20.087336
# SF           85   18.558952
# C            79   17.248908

# %% [markdown]
# # NBA Player Position Distribution Chart

# %%
# Visualize position distribution 

# Count Plot 
plt.figure(figsize=(10, 6))
sns.countplot(x='Position', hue='Position', data=df, palette='rainbow', legend=False)
plt.title('Position Distribution')
plt.show()

# %% [markdown]
# # Breaking Down the NBA: Position-by-Position Analysis
# The NBA is a league of diverse talent, with players specializing in various positions.
#
# Our analysis reveals that Shooting Guards (SG) dominate the league, making up 22.27% of the total players. With 102 players, SGs take the top spot in our position breakdown.
#
# Power Forwards (PF) come in a close second, accounting for 21.83% of the total players. With 100 players, PFs prove to be a crucial part of any NBA team.
#
# Point Guards (PG), Small Forwards (SF), and Centers (C) follow, making up 20.09%, 18.56%, and 17.25% of the total players, respectively.
#
# These insights provide a fascinating glimpse into the world of NBA positions and player distribution.

# %% [markdown]
# # 3. Identify the predominant age group among employees.

# %%
# Calculate age distribution


age_distribution = df['Age'].value_counts(bins=[20, 30, 40, 50, 60], sort=False)
'''The code age_distribution = df['Age'].value_counts(bins=[20, 30, 40, 50, 60], sort=False) means:

Breaking down the code:

- df['Age']: Selects the 'Age' column from the DataFrame df.
- value_counts(): Counts the number of occurrences of each unique value in the 'Age' column.
- bins=[20, 30, 40, 50, 60]: Instead of counting individual ages, group them into bins (or ranges) defined by these values. The bins are:
    - 20-29
    - 30-39
    - 40-49
    - 50-59
- sort=False: By default, value_counts() sorts the results in descending order. Setting sort=False preserves the original order of the bins.'''

# Calculate percentage split
percentage_split = (age_distribution / len(df)) * 100

# Combine results
age_distribution_percentage = pd.concat([age_distribution, percentage_split], axis=1)

# Rename columns
age_distribution_percentage.columns = ['Count', 'Percentage']

# Print results
print(age_distribution_percentage)
# Out:
#                 Count  Percentage
# (19.999, 30.0]    365   79.694323
# (30.0, 40.0]       91   19.868996
# (40.0, 50.0]        0    0.000000
# (50.0, 60.0]        0    0.000000

# %% [markdown]
# # NBA Player Age Distribution Chart

# %%
# Visualize age distribution 

# Histogram
plt.figure(figsize=(10, 6))
plt.hist(df['Age'], bins=[20, 30, 40, 50, 60], edgecolor='black',color='green')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# # Data Story based on NBA Players Age Distribution
#
# Our analysis reveals a striking age distribution among NBA players. The data shows a clear peak in the 20-30 age range, accounting for 79.69% of players.
#
# Age Distribution:
# 20-30: 79.69%
#
# 30-40: 19.87%
#
# 40+: 0.00%
#
# This distribution suggests the NBA is a young person's league, with players in their prime athletic years dominating the court.

# %% [markdown]
# # 4. Discover which team and position have the highest salary expenditure.

# %%
team_salary_expenditure = df.groupby('Team')['Salary'].sum().reset_index()
team_salary_expenditure = team_salary_expenditure.sort_values(by='Salary', ascending=False)
team_salary_expenditure
# Out:
#                       Team        Salary
# 5      Cleveland Cavaliers  1.118227e+08
# 14       Memphis Grizzlies  9.588676e+07
# 12    Los Angeles Clippers  9.485464e+07
# 20   Oklahoma City Thunder  9.376530e+07
# 15              Miami Heat  9.218361e+07
# 9    Golden State Warriors  8.886900e+07
# 4            Chicago Bulls  8.678338e+07
# 26       San Antonio Spurs  8.444273e+07
# 18    New Orleans Pelicans  8.275077e+07
# 3        Charlotte Hornets  7.834092e+07
# 29      Washington Wizards  7.632864e+07
# 10         Houston Rockets  7.528302e+07
# 19         New York Knicks  7.330390e+07
# 0            Atlanta Hawks  7.290295e+07
# 13      Los Angeles Lakers  7.177043e+07
# 25        Sacramento Kings  7.168367e+07
# 6         Dallas Mavericks  7.119873e+07
# 27         Toronto Raptors  7.111761e+07
# 16         Milwaukee Bucks  6.960352e+07
# 8          Detroit Pistons  6.716826e+07
# 11          Indiana Pacers  6.675183e+07
# 7           Denver Nuggets  6.495590e+07
# ...

# %% [markdown]
# #### Insights:
#
# The Cleveland Cavaliers have the highest salary expenditure at approximately $111.8 million.
#
# The top 5 teams with the highest salary expenditure are:
#
# 1. Cleveland Cavaliers ($111.8M)
#
# 2. Memphis Grizzlies ($95.9M)
#
# 3. Los Angeles Clippers ($94.9M)
#
# 4. Oklahoma City Thunder ($93.8M)
#
# 5. Miami Heat ($92.2M)
#
# This data provides valuable insights into the financial commitments of each team.

# %%
# Position salary expenditure
position_salary_expenditure = df.groupby('Position')['Salary'].sum().reset_index()
position_salary_expenditure = position_salary_expenditure.sort_values(by='Salary', ascending=False)
position_salary_expenditure
# Out:
#   Position        Salary
# 0        C  4.663773e+08
# 2       PG  4.661848e+08
# 1       PF  4.570628e+08
# 3       SF  4.128549e+08
# 4       SG  4.114782e+08

# %% [markdown]
# #### Insights:
# The Center (C) position has the highest salary expenditure at approximately $466.4 million.
#
# The top 5 positions with the highest salary expenditure are:
#
# 1. Center (C) ($466.4M)
#
# 2. Point Guard (PG) ($466.2M)
#
# 3. Power Forward (PF) ($457.1M)
#
# 4. Small Forward (SF) ($412.9M)
#
# 5. Shooting Guard (SG) ($411.5M)

# %%
# Pivot table
salary_pivot = df.pivot_table(index='Team', columns='Position', values='Salary', aggfunc='mean')
salary_pivot
# Out:
# Position                           C            PF            PG  \
# Team
# Atlanta Hawks           7.585417e+06  5.988067e+06  4.881700e+06
# Boston Celtics          2.450465e+06  6.056987e+06  4.974652e+06
# Brooklyn Nets           1.031814e+07  3.576205e+06  2.915759e+06
# Charlotte Hornets       6.772240e+06  4.685770e+06  4.776152e+06
# Chicago Bulls           1.042438e+07  3.361007e+06  1.117153e+07
# Cleveland Cavaliers     6.828957e+06  1.394101e+07  6.551592e+06
# Dallas Mavericks        2.332019e+06  3.052835e+06  4.418183e+06
# Denver Nuggets          1.617240e+06  7.024978e+06  3.482413e+06
# Detroit Pistons         4.090697e+06  4.000000e+06  4.260003e+06
# Golden State Warriors   6.541249e+06  7.275312e+06  8.457256e+06
# Houston Rockets         1.165332e+07  1.755114e+06  3.343543e+06
# Indiana Pacers          4.000000e+06  2.064961e+06  4.054692e+06
# Los Angeles Clippers    1.039480e+07  6.655482e+06  8.509072e+06
# ...

# %% [markdown]
# # Visualisation of team and position have the highest salary expenditure

# %%
# Graphical representation of Team salary expenditure 
plt.figure(figsize=(10, 6))
plt.bar(team_salary_expenditure['Team'], team_salary_expenditure['Salary'])
plt.xlabel('Team')
plt.ylabel('Salary Expenditure')
plt.title('Team Salary Expenditure')
plt.xticks(rotation=80)
plt.show()

# Graphical representation of Position salary expenditure
plt.figure(figsize=(14, 9))
plt.bar(position_salary_expenditure['Position'], position_salary_expenditure['Salary'])
plt.xlabel('Position')
plt.ylabel('Salary Expenditure')
plt.title('Position Salary Expenditure')
plt.show()

# Heat map (A heat map is a graphical representation of data where values are depicted by color)
plt.figure(figsize=(10, 8))
sns.heatmap(salary_pivot, annot=True, cmap='Blues')
plt.xlabel('Position')
plt.ylabel('Team')
plt.title('Salary Distribution')
plt.show()

# %% [markdown]
# # Data story based on the team and position have the highest salary expenditure:
#
# NBA Team and Position Salary Expenditure Insights
#
# The NBA is a multi-billion-dollar industry, with teams investing heavily in player salaries. Our analysis reveals interesting insights into team and position salary expenditures.
#
# #### Highest Team Salary Expenditure: Cleveland Cavaliers
#
# Bar chart for Team salary expenditure: This chart shows the total salary expenditure for each team.
#
# The Cleveland Cavaliers top the list with a total salary expenditure of $111.8 million. This significant investment suggests the team is committed to attracting and retaining top talent.
#
# #### Highest Position Salary Expenditure: Center (C)
#
# Bar chart for Position salary expenditure: This chart shows the total salary expenditure for each position.
#
# The Center (C) position has the highest salary expenditure across all teams, with a total of $466.4 million. This is likely due to the crucial role centers play in the game, requiring a unique combination of strength, agility, and endurance.
#
# Notable Team and Position Salary Expenditures
#
# Heatmap for Salary Distribution: This heatmap shows the average salary for each team-position combination, providing a clear visual representation of the salary distribution.
#
# #### - Memphis Grizzlies' Center (C) position has a high salary expenditure of $19,688,000.
#
# #### - Cleveland Cavaliers' Power Forward (PF) position has a high salary expenditure of $13,941,010.
#
# #### - Oklahoma City Thunder's Point Guard (PG) position has a high salary expenditure of $9,382,869.
#
# These insights provide a fascinating glimpse into the financial dynamics of the NBA. By understanding team and position salary expenditures, fans and analysts can better appreciate the strategic decisions made by teams to build competitive rosters.

# %% [markdown]
# # 5.Investigate if there's any correlation between age and salary, and represent it visually.

# %%
# Calculate the correlation between Age and Salary
correlation_coefficient = df['Age'].corr(df['Salary'])
print("Correlation Coefficient:", correlation_coefficient)
# Out:
# Correlation Coefficient: 0.21116954917686367

# %% [markdown]
# # Graphical representation of correlation between age and salary

# %%
# Create a scatter plot of Age vs Salary
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Salary', data=df)
plt.title('Age vs Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# # Data story based on correlation between Age and Salary

# %% [markdown]
# ### Based on the scatter plot, here are some insights:
#
# 1. Weak positive correlation: the correlation coefficient is 0.21, indicating a weak positive relationship between age and salary.
#
# 2. Age distribution: The age distribution appears to be relatively normal, with most players between 20-30 years old.
#
# 3. Outliers: There may be some outliers, such as older players with lower salaries or younger players with higher salaries.
#
# 4. No clear trend: The plot doesn't show a clear trend or pattern, which is consistent with the weak correlation coefficient.
#
# These insights can help you better understand the relationship between age and salary in the NBA.

# %% [markdown]
# # Conclusion:
# In conclusion, this NBA salary analysis has uncovered key trends and insights. The Cleveland Cavaliers lead in team salary expenditure, while Centers command the highest salaries. A weak positive correlation exists between age and salary. The study's findings provide a fascinating glimpse into the NBA's financial landscape, shedding light on strategic team decisions and roster building.
#
# This comprehensive analysis was made possible through a Python-based exploratory data analysis (EDA) of the NBA salary dataset. We investigated correlations between variables, identified outliers, and obtained a knowledge of the distribution of important features using statistical summaries and visualizations. The analysis demonstrated the ability to visualize and analyze complex datasets using Python tools such as Matplotlib, Seaborn, and Pandas. The results provide a thorough understanding of the NBA salary landscape and lay the groundwork for more in-depth studies and modeling.
